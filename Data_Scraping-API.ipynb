# %% [markdown]
# ### Problem Statement - Search for news articles that mention 'bitcoin'

# %%
#Create an API key for NewsApi.org ( or find another site where they are serving News)
#Use that API to create queries.
#Understand the API – Pick a topic , for example: All articles published by the Wall Street Journal in the last 6 months, sorted by recent first
#Fetch the recent articles published about topic you have selected.
#For each article extract the followings– [source-id , source-name, author, title, description, content]
#Convert the JSON output to data frame with each parameter as a column and each article as a row.

# %%
import json
import urllib.request
import pandas as pd
from datetime import datetime

# %% [markdown]
# #### Here we are only getting 100 news articles beyond which the website asks to upgrade the plan. So, let's get the latest hundred articles.

# %%
#newsURL = "http://newsapi.org/v2/top-headlines?country=us&category=business&apiKey=b9fe15a99b3a44df803f8fe5fc9beb23"
#newsURL = "http://newsapi.org/v2/top-headlines?country=us&pageSize=100&apiKey=b9fe15a99b3a44df803f8fe5fc9beb23"
newsURL = ('http://newsapi.org/v2/everything?q=bitcoin&from=2020-07-16&sortBy=publishedAt&pageSize=100&'
           'apiKey=b9fe15a99b3a44df803f8fe5fc9beb23')
newsData = json.load(urllib.request.urlopen(newsURL)) # Load the json response into variable
#print(newsData)
#print(newsData['articles'])
#print(newsData['articles'][0])

# %% [markdown]
# #### Define an empty dataframe with required columns and then populate the same with news articles

# %%
# Define an empty dataframe with required columns
df = pd.DataFrame(columns = ['source-id', 'source-name', 'author', 'title', 'description', 'content','url','publishedAt'])

# Let's populate the dataframe columns in for loop
for article in newsData['articles']:
    df = df.append({'source-id' :  article['source']['id'], 'source-name' : article['source']['name'], \
                    'author' : article['author'], 'title' : article['title'], 'description' : article['description'],\
                    'content' : article['content'], 'url' : article['url'], 'publishedAt' : article['publishedAt'] }, \
                   ignore_index = True)
    
#print(df)

# %% [markdown]
# #### Though we have got the data sorted based on publish date (publishedAT) but let's sort the data explicitly to avoid any shuffling

# %%
#date1 = datetime.now().strftime("%Y-%m-%dT%H:%M:%SZ") 
#print(date1)
#date2 = datetime.now().strftime("%Y-%m-%d::%H:%M:%S") 
#print(date2)
df['publishedAt'] = pd.to_datetime(df['publishedAt'], format="%Y-%m-%dT%H:%M:%SZ")
df.sort_values(by=['publishedAt'], inplace=True, ascending=False)

# %% [markdown]
# #### Printing the final dataframe before writing into CSV file

# %%
df
# Out:
#            source-id          source-name                             author  \
# 0               None          Boing Boing                 Boing Boing's Shop
# 1               None  Yahoo Entertainment                          Bob Mason
# 2               None              newsBTC                         Nick Chong
# 3               None           Bitcoinist                         Nick Chong
# 4               None        Cointelegraph       Cointelegraph By Ray Salmond
# ..               ...                  ...                                ...
# 95  business-insider     Business Insider                      Emily Graffeo
# 96              None              newsBTC                      Tony Spilotro
# 97              None           PRNewswire                               None
# 98              None  Yahoo Entertainment                        PR Newswire
# 99              None        Cointelegraph  Cointelegraph By Michael Kapilkov
#
#                                                 title  \
# 0   Here are 10 good reasons you should hop on the...
# 1   The Crypto Daily – Movers and Shakers – August...
# 2   Is Bitcoin Really In a Bull Market? Here’s Why...
# 3   These 4 Factors Show Why It’s Hard to Be Beari...
# 4   Bulls Stampede Toward $12K Bitcoin Price as We...
# ..                                                ...
# 95  Gold 'certainly' could soar as high as $3000, ...
# 96  Indicator Shows XRP Has Most Explosive Momentu...
# 97  Controllable Load Resource ("CLR") Market Lead...
# 98  Controllable Load Resource ("CLR") Market Lead...
# 99  Grayscale Investments Enjoys Its Best Week Eve...
#
#                                           description  \
# 0   Ever since the great TP shortage of 2020, it's...
# 1   It’s a bearish start to the day, Failure to mo...
# 2   Bitcoin has done extremely well over the past ...
# 3   There remain some Bitcoin bears despite the on...
# 4   Bitcoin price continues to meet resistance at ...
# ..                                                ...
# 95  <ul>\n<li>Michael Novogratz told Bloomberg the...
# 96  XRP’s recent rally has taken a pause, leaving ...
# 97  HOUSTON, Aug. 14, 2020 /PRNewswire/ -- Lancium...
# 98  Lancium LLC, the leader in data center power r...
# 99                The power of television is no joke.
#
#                                               content  \
# 0   Ever since the great TP shortage of 2020, it's...
# 1   Bitcoin, BTC to USD, rose by 0.70% on Saturday...
# 2   Bitcoin has done extremely well over the past ...
# 3   <ul><li>There remain some Bitcoin bears despit...
# 4   <ul><li>Bitcoin price is making a strong push ...
# ..                                                ...
# 95  REUTERS/Rick Wilking\r\n<ul><li>Michael Novogr...
# 96  XRP’s recent rally has taken a pause, leaving ...
# 97  HOUSTON, Aug. 14, 2020 /PRNewswire/ -- Lancium...
# 98  HOUSTON, Aug. 14, 2020 /PRNewswire/ -- Lancium...
# 99  Grayscale Investments had its best fundraising...
#
#                                                   url         publishedAt
# 0   https://boingboing.net/2020/08/15/here-are-10-... 2020-08-16 02:00:00
# 1   https://finance.yahoo.com/news/crypto-daily-mo... 2020-08-16 00:28:22
# 2   https://www.newsbtc.com/2020/08/16/bitcoin-rea... 2020-08-16 00:00:19
# 3   https://bitcoinist.com/5-factors-hard-bearish-... 2020-08-15 23:59:14
# 4   https://cointelegraph.com/news/bulls-stampede-... 2020-08-15 23:32:00
# ..                                                ...                 ...
# 95  https://www.businessinsider.com/gold-price-out... 2020-08-14 20:13:44
# 96  https://www.newsbtc.com/2020/08/14/xrp-strengt... 2020-08-14 20:00:23
# 97  https://www.prnewswire.com/news-releases/contr... 2020-08-14 19:57:00
# 98  https://news.yahoo.com/controllable-load-clr-m... 2020-08-14 19:57:00
# 99  https://cointelegraph.com/news/grayscale-inves... 2020-08-14 19:41:00
#
# [100 rows x 8 columns]

# %% [markdown]
# #### Write the dataframe to CSV file

# %%
df.to_csv('./NewsApi_Anuroop_Ajmera.csv', index=False)
